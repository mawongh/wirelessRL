# %%
# the required imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the random policy results
path = '/home/mawongh/ws/datasets/model-based_results/'
rnd = pd.read_csv(path + '170821_randompolicy_for_benchmark.csv')
dqn_50k_e01 = pd.read_csv(path + '170914_DQN_50K_g09_history.csv').tail(10000)
dqn_50k_e01['epsilon'] = np.repeat(0.1, len(dqn_50k_e01))
data = pd.concat([rnd, dqn_50k_e01], ignore_index=True)
names = data.columns.values
names[1] = 'step'
data.columns = names
data.tail(3)
# Out:
#        00_episode  step                                              state  \
# 19997          99   497  [2733 2733 2733 3200 3200 3200 2500 2500 2500 ...
# 19998          99   498  [2733 2733 2733 3200 3200 3200 2500 2500 2500 ...
# 19999          99   499  [2733 2733 2733 3200 3200 3200 2500 2500 2500 ...
#
#        action    reward                                          new_state  \
# 19997     114 -6.091702  [2733 2733 2733 3200 3200 3200 2500 2500 2500 ...
# 19998     114 -7.299313  [2733 2733 2733 3200 3200 3200 2500 2500 2500 ...
# 19999     114 -6.088707  [2733 2733 2733 3200 3200 3200 2500 2500 2500 ...
#
#        epsilon  terminal
# 19997      0.1     False
# 19998      0.1     False
# 19999      0.1     False

# %%
sns.set()
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=0.7)
plt.figure(figsize = (6,3.5), dpi = 200)
sns.tsplot(data = data, time = 'step', value = 'reward',
           unit='00_episode', condition = 'epsilon')
plt.show()
# Out:
# /home/mawongh/anaconda3/envs/rl/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
plt.hist(dqn_50k_e01.action, bins=126)
plt.show()
