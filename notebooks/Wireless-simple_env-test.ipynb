# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
conf_filepath = '../simple_env_conf.csv'
site_conf = pd.read_csv(conf_filepath)
site_conf
# Out:
#     #siteid  nodeid   lon   lat  height  azimuth  beamwidth  txpower  gain
# 0         1       0  1266  2733      30        0         60       43     0
# 1         1       1  1266  2733      30      120         60       43     0
# 2         1       2  1266  2733      30      240         60       43     0
# 3         2       3  1733  3200      30        0         60       43     0
# 4         2       4  1733  3200      30      120         60       43     0
# 5         2       5  1733  3200      30      240         60       43     0
# 6         3       6  1600  2500      30        0         60       43     0
# 7         3       7  1600  2500      30      120         60       43     0
# 8         3       8  1600  2500      30      240         60       43     0
# 9         4       9   700  4266      30        0         60       43     0
# 10        4      10   700  4266      30      120         60       43     0
# ...

# %%
filename = '/Volumes/ws/bake/source/ns-3.26/scratch/lena-simple_env.rem'
rem = pd.read_csv(filename, sep='\t', header=None)
# rem.head()
plt.figure(figsize=(9,8))
plt.scatter(rem.loc[:,0], rem.loc[:,1], c = 10*np.log(rem.loc[:,3]), marker='s', edgecolors='none')
plt.colorbar()
plt.show()
